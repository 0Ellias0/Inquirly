# %%
import pandas as pd
import matplotlib.pyplot as plt

# %%
df = pd.read_csv(r"Paused.csv",sep=';')
df.fillna(0, inplace=True)

# %%
df
# Out:
#                                Company Name               Name        Phone  \
# 0                    Coast View Restoration  Amjad Khanmohamed  ?3109187162
# 1      1-800 Water Damage of Pembroke Pines    Patrick Nedrick  ?7863518007
# 2               Best Option Restoration CHV      Kyle Chiasson  ?7204955953
# 3            All Dry Services of Bear River     Robert Galeria  ?8056302072
# 4               Destiny property management    Steven catalano  ?6313572405
# ..                                      ...                ...          ...
# 255                     Patriot Restoration        TJ Wiberley            0
# 256  All Dry Services of Greater Harrisburg     Phillip Snyder            0
# 257      American Restoration Professionals      Dan Hennessey            0
# 258    Integral Restoration Harding Drywall      Chris Harding            0
# 259    All Dry Services of The Jersey Shore     Robert Walters            0
#
#                                         Email   Status     Balance  \
# 0              coastviewrestoration@gmail.com  Stopped  2,750.00 $
# 1         patrick.nedrick@1800waterdamage.com  Stopped  2,450.00 $
# 2                    kc@chv-borestoration.com  Stopped  1,750.00 $
# 3                 rachel.galeria@myalldry.com  Stopped  1,730.00 $
# 4                stevencatalano@destinypm.com  Stopped  1,555.00 $
# ..                                        ...      ...         ...
# 255       tjwiberley@patriotrestorationtn.com        0    300.00 $
# 256               phillip.snyder@myalldry.com        0    580.00 $
# 257  dan@americanrestorationprofessionals.com        0    800.00 $
# 258               chrisharding_74@hotmail.com        0    600.00 $
# 259               robert.walters@myalldry.com        0    575.00 $
#
#             Date Created Paused Date     Emailed           Called  \
# 0       19/09/2022 13:37           0  06/21/2023                0
# 1       29/12/2022 23:59  06/21/2023  06/21/2023  No- Msg mistake
# 2        13/10/2021 9:59  10/05/2023  06/21/2023                0
# 3        3/11/2022 19:00  05/23/2023  06/21/2023                0
# 4        9/03/2023 11:27   4/04/2023  06/21/2023                0
# ..                   ...         ...         ...              ...
# 255  03/21/2022 13:00:12  06/26/2023  08/14/2023                0
# 256      3/10/2022 12:48  07/23/2023  08/14/2023                0
# 257  02/19/2022 10:08:12  07/25/2023  08/14/2023                0
# 258                    0   7/06/2023  08/14/2023                0
# 259                    0   7/08/2023  08/14/2023                0
#
#             Status.1
# 0                  0
# 1    Will Reactivate
# 2      Not Ready Yet
# 3       Didn't Reply
# 4    Will Reactivate
# ..               ...
# 255                0
# 256                0
# 257                0
# 258                0
# 259                0
#
# [260 rows x 11 columns]

# %%
# Replace empty values with "Blank"
df['Status'].fillna("Blank", inplace=True)

# Count the occurrences of each value in the "Status" column
status_counts = df['Status.1'].value_counts()

# %%
print(status_counts)
# Out:
# Stopped    250
# 0           10
# Name: Status, dtype: int64
