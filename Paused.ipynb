# %%
import pandas as pd
import matplotlib.pyplot as plt

# %%
df = pd.read_csv(r"Paused2.csv",sep=';')
df.fillna(0, inplace=True)

# %%
df
# Out:
#    Email Sent                  Status 2
# 0   8/07/2023  OnBo Done, Pending Funds
# 1   8/07/2023                  No Reply
# 2   8/07/2023         Active with Funds
# 3           0         Active with Funds
# 4   8/08/2023                  No Reply
# 5   8/08/2023  OnBo Done, Pending Funds
# 6   8/08/2023                  No Reply
# 7   8/09/2023         Active with Funds
# 8   8/11/2023                  No Reply
# 9   8/11/2023                  No Reply
# 10  8/11/2023                  No Reply
# 11  8/11/2023                  No Reply
# 12  8/11/2023                  No Reply
# 13  8/11/2023                  No Reply
# 14          0         Active with Funds
# 15  8/11/2023                  No Reply
# 16   08/14/23                    Closed
# 17   07/25/23                  No Reply
# 18   08/14/23                         0
# 19   08/14/23                  No Reply
# 20          0         Active with Funds
# 21   07/25/23         Active with Funds
# ...

# %%
# Replace empty values with "Blank"
df['Status 2'].fillna("Blank", inplace=True)

# Count the occurrences of each value in the "Status" column
status_counts = df['Status 2'].value_counts()

# %%
print(status_counts)
# Out:
# No Reply                    17
# Active with Funds            6
# OnBo Done, Pending Funds     3
# 0                            2
# Closed                       1
# Name: Status 2, dtype: int64
